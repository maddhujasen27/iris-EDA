# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### LOADING DATA

# %%
from sklearn.datasets import load_iris 
iris = load_iris()

# %% [markdown]
# <img src="https://miro.medium.com/max/1000/1*Hh53mOF4Xy4eORjLilKOwA.png" width = '300'>

# %%
df = pd.DataFrame(data = iris.data, columns = iris.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df['species'] = iris.target

# %% [markdown]
# ### UNDERSTANDING THE DATA

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %%
df.columns.values
# Out:
# array(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'], dtype=object)

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     species
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
df.isnull().any()
# Out:
# sepal length (cm)    False
# sepal width (cm)     False
# petal length (cm)    False
# petal width (cm)     False
# species              False
# dtype: bool

# %%
df['species'].value_counts()
# Out:
# 2    50
# 1    50
# 0    50
# Name: species, dtype: int64

# %%
print("Sepal length (cm) : max = ",df['sepal length (cm)'].max()," min = ",df['sepal length (cm)'].min())
print("Sepal width (cm)  : max = ",df['sepal width (cm)'].max()," min = ",df['sepal width (cm)'].min())
print("Petal width (cm)  : max = ",df['petal width (cm)'].max()," min = ",df['petal width (cm)'].min())
print("Petal length (cm) : max = ",df['petal length (cm)'].max()," min = ",df['petal length (cm)'].min())
# Out:
# Sepal length (cm) : max =  7.9  min =  4.3
# Sepal width (cm)  : max =  4.4  min =  2.0
# Petal width (cm)  : max =  2.5  min =  0.1
# Petal length (cm) : max =  6.9  min =  1.0

# %% [markdown]
# ### DATA VISUALIZATION

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# #### SCATTER PLOT

# %%
plt.scatter(df['petal length (cm)'],df['sepal length (cm)'], color = 'orange')
plt.xlabel("petal length (cm)")
plt.ylabel("sepal length (cm)")
plt.title("Plotting petal length (cm) VS sepal length (cm) in Scatter Plot")
plt.show()

# %%
plt.plot(df['petal width (cm)'],df['sepal width (cm)'])
plt.scatter(df['petal width (cm)'],df['sepal width (cm)'], color = "red")
plt.xlabel("petal width (cm)")
plt.ylabel("sepal width (cm)")
plt.title("Petal width (cm) VS Sepal width (cm)")
plt.show()

# %%
plt.scatter(df['petal width (cm)'],df['petal length (cm)'], color = "red")
plt.xlabel("petal width (cm)")
plt.ylabel("petal length (cm)")
plt.title("Petal width (cm) VS Petal length (cm)")
plt.show()

# %%
plt.scatter(df['sepal width (cm)'],df['sepal length (cm)'], color = "green")
plt.xlabel("sepal width (cm)")
plt.ylabel("sepal length (cm)")
plt.title("Sepal width (cm) VS Sepal length (cm)")
plt.show()

# %%
plt.figure(figsize = (9, 7))
plt.scatter(df['sepal length (cm)'], df['petal length (cm)'])
plt.scatter(df['sepal width (cm)'], df['petal length (cm)'])
plt.legend(['length','width'])

# %%
plt.figure(figsize = (9, 7))
sns.swarmplot(x = 'species', y = 'petal length (cm)', data = df)

# %% [markdown]
# #### BAR PLOT

# %%
plt.bar(df['species'],df['sepal length (cm)'])
plt.xlabel("Species")
plt.ylabel("sepal length (cm)")
plt.title("Species VS Sepal length (cm)")
plt.show()

# %%
plt.bar(df['species'],df['sepal width (cm)'],color = "green")
plt.xlabel("Species")
plt.ylabel("sepal width (cm)")
plt.title("Species VS Sepal width (cm)")
plt.show()

# %%
plt.bar(df['species'],df['petal width (cm)'],color = "yellow")
plt.xlabel("Species")
plt.ylabel("petal width (cm)")
plt.title("Species VS Petal width (cm)")
plt.show()

# %%
plt.bar(df['species'],df['petal length (cm)'],color = "orange")
plt.xlabel("Species")
plt.ylabel("petal length (cm)")
plt.title("Species VS Petal length (cm)")
plt.show()

# %% [markdown]
# #### COUNT PLOT

# %%
sns.countplot(x = 'species', data = df , palette = "Oranges_d")

# %% [markdown]
# #### HISTOGRAM

# %%
plt.hist(df['sepal length (cm)'], bins = 20, rwidth = 0.8, color = "pink")
plt.xlabel("sepal length (cm)")
plt.ylabel("Count")
plt.show()

# %%
plt.hist(df['sepal width (cm)'], bins = 20, rwidth = 0.8)
plt.xlabel("sepal width (cm)")
plt.ylabel("Count")
plt.show()

# %%
plt.hist(df['petal length (cm)'], bins = 20, rwidth = 0.8, color = "purple")
plt.xlabel("petal length (cm)")
plt.ylabel("Count")
plt.show()

# %%
plt.hist(df['petal width (cm)'], bins = 20, rwidth = 0.8, color = "green")
plt.xlabel("petal width (cm)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #### FACTOR PLOT

# %%
sns.factorplot(x = 'species', y  = 'sepal length (cm)' , data = df)
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# #### BOXPLOT

# %%
sns.boxplot(data = df, orient= 'h')

# %% [markdown]
# #### PAIR PLOT

# %%
f = sns.PairGrid(df)
f.map(plt.scatter)

# %%
sns.pairplot(df, kind= 'reg', diag_kind='kde', palette='husl', hue= 'species')

# %% [markdown]
# #### JOINT PLOT

# %%
sns.jointplot(x = 'sepal length (cm)',y = 'sepal width (cm)', data = df, kind = 'kde')

# %% [markdown]
# #### HEATMAP

# %%
sns.heatmap(df)

# %%
sns.heatmap(df.corr(), annot = True)
